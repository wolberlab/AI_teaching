# %%
import logging

# Disable RDKit logging
logger = logging.getLogger('rdkit')
logger.disabled = True
import rdkit
print(rdkit.__version__)
from rdkit import Chem
import numpy as np
import pandas as pd
from rdkit.Chem import AllChem, PandasTools
# Out:
# 2021.03.2

# %%
'''
The activity data (IC50) of compounds tested on PPAR_gamma (homo sapiens) were downloaded from ChEMBL (CHEMBL235). 

'''
dfic50 = pd.read_csv('./data_sets/ppar_gamma_ic50.csv', delimiter=';')

# %%
len(dfic50)
# Out:
# 2261

# %%
dfic50.dropna(subset = ['Smiles'],inplace=True)
dfic50["Standard Units"].unique(), dfic50['Standard Relation'].unique()
# Out:
# (array(['nM', nan], dtype=object),
#  array(["'='", nan, "'>'", "'<'"], dtype=object))

# %%
dfic50_1 = dfic50[dfic50['Standard Relation']=="'='"]
dfic50_2 = dfic50.loc[(dfic50['Standard Relation']=="'>'")|(dfic50['Standard Relation']=="'>='")]
dfic50_3 = dfic50[dfic50['Standard Relation'].isna()]
len(dfic50_1), len(dfic50_2), len(dfic50_3)
# Out:
# (1911, 218, 117)

# %%
#Only the compounds with IC50 tested and pChEMBL values calculated were selected for further processing and analysis. 
dfic50_1.dropna(subset = ['pChEMBL Value'],inplace=True)
len(dfic50_1)
# Out:
# /tmp/ipykernel_1532412/2328096240.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfic50_1.dropna(subset = ['pChEMBL Value'],inplace=True)
# 1903

# %%
dfic50_1
# Out:
#      Molecule ChEMBL ID  Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0          CHEMBL111271            NaN                 NaN            508.59
# 1          CHEMBL121106            NaN                 NaN            357.44
# 2          CHEMBL121106            NaN                 NaN            357.44
# 4         CHEMBL2037081            NaN                 NaN            486.49
# 5         CHEMBL3695875            NaN                 NaN            508.67
# ...                 ...            ...                 ...               ...
# 2256        CHEMBL82293  PALMITIC ACID                -1.0            256.43
# 2257         CHEMBL8659     OLEIC ACID                 2.0            282.47
# 2258      CHEMBL1173474   BEHENIC ACID                 NaN            340.59
# 2259      CHEMBL3695916            NaN                 NaN            558.72
# 2260          CHEMBL121  ROSIGLITAZONE                 4.0            357.44
#
#       #RO5 Violations  AlogP Compound Key  \
# 0                   2   6.98           25
# 1                   0   2.49           1a
# 2                   0   2.49           1a
# 4                   1   6.09           70
# 5                   2   8.62   BDBM147320
# ...               ...    ...          ...
# 2256                1   5.55            4
# 2257                1   6.11            9
# 2258                1   7.89            7
# 2259                2   8.68           55
# 2260                0   2.49            1
#
#                                                  Smiles Standard Type  \
# 0     CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1ccc2c(c1)OC(CC...          IC50
# 1          CN(CCOc1ccc(C[C@@H]2SC(=O)NC2=O)cc1)c1ccccn1          IC50
# 2          CN(CCOc1ccc(C[C@@H]2SC(=O)NC2=O)cc1)c1ccccn1          IC50
# 4     Cc1oc(-c2ccc(C(F)(F)F)cc2)nc1Cn1ccc2cc(C[C@@H]...          IC50
# 5     Cc1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2ccc(C(=O)N[C@@...          IC50
# ...                                                 ...           ...
# 2256                              CCCCCCCCCCCCCCCC(=O)O          IC50
# 2257                         CCCCCCCC/C=C\CCCCCCCC(=O)O          IC50
# 2258                        CCCCCCCCCCCCCCCCCCCCCC(=O)O          IC50
# 2259  CC[C@H](NC(=O)c1ccc2c(c1)c(C)c(C)n2Cc1ccc(-c2c...          IC50
# 2260            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1          IC50
#
#      Standard Relation  ...  Document ChEMBL ID Source ID  \
# 0                  '='  ...       CHEMBL1149176         1
# 1                  '='  ...       CHEMBL1130725         1
# 2                  '='  ...       CHEMBL1130725         1
# 4                  '='  ...       CHEMBL2034870         1
# 5                  '='  ...       CHEMBL3638687        37
# ...                ...  ...                 ...       ...
# 2256               '='  ...       CHEMBL3046720         1
# 2257               '='  ...       CHEMBL3046720         1
# 2258               '='  ...       CHEMBL3046720         1
# 2259               '='  ...       CHEMBL3734690         1
# 2260               '='  ...       CHEMBL1149440         1
#
#                      Source Description      Document Journal Document Year  \
# 0                 Scientific Literature            J Med Chem        2004.0
# 1                 Scientific Literature  Bioorg Med Chem Lett        1998.0
# 2                 Scientific Literature  Bioorg Med Chem Lett        1998.0
# 4                 Scientific Literature       Bioorg Med Chem        2012.0
# 5     BindingDB Patent Bioactivity Data                   NaN        2015.0
# ...                                 ...                   ...           ...
# 2256              Scientific Literature          Med Chem Res        2013.0
# 2257              Scientific Literature          Med Chem Res        2013.0
# 2258              Scientific Literature          Med Chem Res        2013.0
# 2259              Scientific Literature     ACS Med Chem Lett        2015.0
# 2260              Scientific Literature            J Med Chem        2006.0
#
#      Cell ChEMBL ID  Properties  Action Type  Standard Text Value    Value
# 0               NaN         NaN          NaN                  NaN    1.200
# 1               NaN         NaN          NaN                  NaN    0.030
# 2               NaN         NaN          NaN                  NaN    0.060
# 4               NaN         NaN          NaN                  NaN    6.857
# 5               NaN         NaN          NaN                  NaN  256.000
# ...             ...         ...          ...                  ...      ...
# 2256            NaN         NaN          NaN                  NaN   30.000
# 2257            NaN         NaN          NaN                  NaN    4.100
# 2258            NaN         NaN          NaN                  NaN   30.000
# 2259            NaN         NaN          NaN                  NaN    9.000
# 2260            NaN         NaN          NaN                  NaN    0.092
#
# [1903 rows x 48 columns]

# %%
len(dfic50_1[dfic50_1['pChEMBL Value']>=6]),len(dfic50_1[dfic50_1['pChEMBL Value']<6])
# Out:
# (1259, 644)

# %%
import sys
sys.path.append('/home/sliu/cyp_related_coding/CYP19_inhibitor_screening/')
'''
The following function used for molecule preprocessing is from 'RingSySTEMS' project: https://github.com/anya-chen/RingSystems/tree/master/Preprocessing/src
'''
from src import MoleculePreprocessor
from src.MoleculePreprocessor import MoleculePreprocessor
from src.MoleculePreprocessorExtended import MoleculePreprocessorExtended

# %%
moleculesProcessed = MoleculePreprocessorExtended.init_with_smiles(list(dfic50_1.Smiles))

# %%
from rdkit import RDLogger
moleculesProcessed.csp_wash()

# %%
preprocessedSmilesDict = moleculesProcessed.get_rawsmiles_smiles_dict()

# %%
preprocessedSmiles_df = pd.DataFrame(list(preprocessedSmilesDict.items()), columns=['rawSmiles','preprocessedSmiles'])

# %%
preprocessed_df = pd.merge(dfic50_1, preprocessedSmiles_df, 
                           left_on='Smiles', right_on='rawSmiles')

# %%
preprocessed_df.dropna(subset=['preprocessedSmiles'],inplace=True)

# %%
preprocessed_df = preprocessed_df[preprocessed_df['preprocessedSmiles']!='']

# %%
len(preprocessed_df)
# Out:
# 1900

# %%
# Use the loc method to set the values in the new column based on the values in the existing column
preprocessed_df.loc[preprocessed_df['pChEMBL Value']>=6, 'y_true_label'] = '1'
preprocessed_df.loc[preprocessed_df['pChEMBL Value']<6, 'y_true_label'] = '0'

# %%
def remove_stereochemistry(smiles):
    # Convert the SMILES string to an RDKit molecule object
    mol = Chem.MolFromSmiles(smiles)
    
    # Use the Chem.RemoveStereochemistry function to remove stereo informationz
    Chem.RemoveStereochemistry(mol)
    
    # Convert the molecule back to a SMILES string without stereochemistry
    return Chem.MolToSmiles(mol)

preprocessed_df['preprocessedSmiles'] = preprocessed_df['preprocessedSmiles'].apply(remove_stereochemistry)
preprocessed_df
# Out:
#      Molecule ChEMBL ID  Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0          CHEMBL111271            NaN                 NaN            508.59
# 1          CHEMBL121106            NaN                 NaN            357.44
# 2          CHEMBL121106            NaN                 NaN            357.44
# 3          CHEMBL121106            NaN                 NaN            357.44
# 4         CHEMBL2037081            NaN                 NaN            486.49
# ...                 ...            ...                 ...               ...
# 1898          CHEMBL150     KAEMPFEROL                 NaN            286.24
# 1899       CHEMBL379064   ISORHAMNETIN                 NaN            316.26
# 1900        CHEMBL82293  PALMITIC ACID                -1.0            256.43
# 1901         CHEMBL8659     OLEIC ACID                 2.0            282.47
# 1902      CHEMBL1173474   BEHENIC ACID                 NaN            340.59
#
#       #RO5 Violations  AlogP     Compound Key  \
# 0                   2   6.98               25
# 1                   0   2.49               1a
# 2                   0   2.49               1a
# 3                   0   2.49               86
# 4                   1   6.09               70
# ...               ...    ...              ...
# 1898                0   2.28               20
# 1899                0   2.29  1; Isorhamnetin
# 1900                1   5.55                4
# 1901                1   6.11                9
# 1902                1   7.89                7
#
#                                                  Smiles Standard Type  \
# 0     CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1ccc2c(c1)OC(CC...          IC50
# 1          CN(CCOc1ccc(C[C@@H]2SC(=O)NC2=O)cc1)c1ccccn1          IC50
# 2          CN(CCOc1ccc(C[C@@H]2SC(=O)NC2=O)cc1)c1ccccn1          IC50
# 3          CN(CCOc1ccc(C[C@@H]2SC(=O)NC2=O)cc1)c1ccccn1          IC50
# 4     Cc1oc(-c2ccc(C(F)(F)F)cc2)nc1Cn1ccc2cc(C[C@@H]...          IC50
# ...                                                 ...           ...
# 1898            O=c1c(O)c(-c2ccc(O)cc2)oc2cc(O)cc(O)c12          IC50
# 1899            COc1cc(-c2oc3cc(O)cc(O)c3c(=O)c2O)ccc1O          IC50
# 1900                              CCCCCCCCCCCCCCCC(=O)O          IC50
# 1901                         CCCCCCCC/C=C\CCCCCCCC(=O)O          IC50
# 1902                        CCCCCCCCCCCCCCCCCCCCCC(=O)O          IC50
#
#      Standard Relation  ...      Document Journal Document Year  \
# 0                  '='  ...            J Med Chem        2004.0
# 1                  '='  ...  Bioorg Med Chem Lett        1998.0
# 2                  '='  ...  Bioorg Med Chem Lett        1998.0
# 3                  '='  ...        Eur J Med Chem        2011.0
# 4                  '='  ...       Bioorg Med Chem        2012.0
# ...                ...  ...                   ...           ...
# 1898               '='  ...        Eur J Med Chem        2021.0
# 1899               '='  ...        Eur J Med Chem        2021.0
# 1900               '='  ...          Med Chem Res        2013.0
# 1901               '='  ...          Med Chem Res        2013.0
# 1902               '='  ...          Med Chem Res        2013.0
#
#       Cell ChEMBL ID Properties Action Type Standard Text Value    Value  \
# 0                NaN        NaN         NaN                 NaN    1.200
# 1                NaN        NaN         NaN                 NaN    0.030
# 2                NaN        NaN         NaN                 NaN    0.060
# 3                NaN        NaN         NaN                 NaN  210.000
# 4                NaN        NaN         NaN                 NaN    6.857
# ...              ...        ...         ...                 ...      ...
# 1898             NaN        NaN     AGONIST                 NaN   23.100
# 1899             NaN        NaN  ANTAGONIST                 NaN    3.500
# 1900             NaN        NaN         NaN                 NaN   30.000
# 1901             NaN        NaN         NaN                 NaN    4.100
# 1902             NaN        NaN         NaN                 NaN   30.000
#
#                                               rawSmiles  \
# 0     CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1ccc2c(c1)OC(CC...
# 1          CN(CCOc1ccc(C[C@@H]2SC(=O)NC2=O)cc1)c1ccccn1
# 2          CN(CCOc1ccc(C[C@@H]2SC(=O)NC2=O)cc1)c1ccccn1
# 3          CN(CCOc1ccc(C[C@@H]2SC(=O)NC2=O)cc1)c1ccccn1
# 4     Cc1oc(-c2ccc(C(F)(F)F)cc2)nc1Cn1ccc2cc(C[C@@H]...
# ...                                                 ...
# 1898            O=c1c(O)c(-c2ccc(O)cc2)oc2cc(O)cc(O)c12
# 1899            COc1cc(-c2oc3cc(O)cc(O)c3c(=O)c2O)ccc1O
# 1900                              CCCCCCCCCCCCCCCC(=O)O
# 1901                         CCCCCCCC/C=C\CCCCCCCC(=O)O
# 1902                        CCCCCCCCCCCCCCCCCCCCCC(=O)O
#
#                                      preprocessedSmiles  y_true_label
# 0     CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1ccc2c(c1)OC(CC...             0
# 1             CN(CCOc1ccc(Cc2sc(=O)[nH]c2O)cc1)c1ccccn1             1
# 2             CN(CCOc1ccc(Cc2sc(=O)[nH]c2O)cc1)c1ccccn1             1
# 3             CN(CCOc1ccc(Cc2sc(=O)[nH]c2O)cc1)c1ccccn1             1
# 4     Cc1oc(-c2ccc(C(F)(F)F)cc2)nc1Cn1ccc2cc(CC(OC(C...             1
# ...                                                 ...           ...
# 1898            O=c1c(O)c(-c2ccc(O)cc2)oc2cc(O)cc(O)c12             0
# 1899            COc1cc(-c2oc3cc(O)cc(O)c3c(=O)c2O)ccc1O             0
# 1900                              CCCCCCCCCCCCCCCC(=O)O             0
# 1901                           CCCCCCCCC=CCCCCCCCC(=O)O             0
# 1902                        CCCCCCCCCCCCCCCCCCCCCC(=O)O             0
#
# [1900 rows x 51 columns]

# %%
duplicates = preprocessed_df.duplicated('preprocessedSmiles', keep=False)

# Filter DataFrame to list duplicates with their information
duplicates_df = preprocessed_df[duplicates]
duplicates_df
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 1          CHEMBL121106           NaN                 NaN            357.44
# 2          CHEMBL121106           NaN                 NaN            357.44
# 3          CHEMBL121106           NaN                 NaN            357.44
# 4         CHEMBL2037081           NaN                 NaN            486.49
# 8         CHEMBL3699355           NaN                 NaN            638.61
# ...                 ...           ...                 ...               ...
# 1868       CHEMBL424133     LY-518674                 2.0            409.49
# 1869       CHEMBL424133     LY-518674                 2.0            409.49
# 1881      CHEMBL3695816           NaN                 NaN            532.60
# 1882      CHEMBL3695816           NaN                 NaN            532.60
# 1892       CHEMBL116774           NaN                 NaN            467.56
#
#       #RO5 Violations  AlogP Compound Key  \
# 1                   0   2.49           1a
# 2                   0   2.49           1a
# 3                   0   2.49           86
# 4                   1   6.09           70
# 8                   2   9.20   BDBM147372
# ...               ...    ...          ...
# 1868                0   3.76            5
# 1869                0   3.76           42
# 1881                2   6.33           2c
# 1882                2   6.33   BDBM147258
# 1892                0   4.81           17
#
#                                                  Smiles Standard Type  \
# 1          CN(CCOc1ccc(C[C@@H]2SC(=O)NC2=O)cc1)c1ccccn1          IC50
# 2          CN(CCOc1ccc(C[C@@H]2SC(=O)NC2=O)cc1)c1ccccn1          IC50
# 3          CN(CCOc1ccc(C[C@@H]2SC(=O)NC2=O)cc1)c1ccccn1          IC50
# 4     Cc1oc(-c2ccc(C(F)(F)F)cc2)nc1Cn1ccc2cc(C[C@@H]...          IC50
# 8     Cc1c(C)n(Cc2ccc(-c3ccccc3C(=O)O)cc2)c2ccc(C(=O...          IC50
# ...                                                 ...           ...
# 1868  Cc1ccc(Cn2nc(CCCc3ccc(OC(C)(C)C(=O)O)cc3)nc2O)cc1          IC50
# 1869  Cc1ccc(Cn2nc(CCCc3ccc(OC(C)(C)C(=O)O)cc3)nc2O)cc1          IC50
# 1881  Cc1c(C)n(Cc2ccc(-c3ccccc3C(=O)O)cc2)c2ccc(C(=O...          IC50
# 1882  Cc1c(C)n(Cc2ccc(-c3ccccc3C(=O)O)cc2)c2ccc(C(=O...          IC50
# 1892  CCCc1cc(C2CCC(O)CC2)ccc1OCCCOc1cccc(C2OC(=O)NC...          IC50
#
#      Standard Relation  ...      Document Journal Document Year  \
# 1                  '='  ...  Bioorg Med Chem Lett        1998.0
# 2                  '='  ...  Bioorg Med Chem Lett        1998.0
# 3                  '='  ...        Eur J Med Chem        2011.0
# 4                  '='  ...       Bioorg Med Chem        2012.0
# 8                  '='  ...                   NaN        2015.0
# ...                ...  ...                   ...           ...
# 1868               '='  ...            J Med Chem        2003.0
# 1869               '='  ...       Bioorg Med Chem        2012.0
# 1881               '='  ...  Bioorg Med Chem Lett        2019.0
# 1882               '='  ...                   NaN        2015.0
# 1892               '='  ...  Bioorg Med Chem Lett        2003.0
#
#       Cell ChEMBL ID Properties Action Type Standard Text Value     Value  \
# 1                NaN        NaN         NaN                 NaN     0.030
# 2                NaN        NaN         NaN                 NaN     0.060
# 3                NaN        NaN         NaN                 NaN   210.000
# 4                NaN        NaN         NaN                 NaN     6.857
# 8                NaN        NaN         NaN                 NaN    11.000
# ...              ...        ...         ...                 ...       ...
# 1868             NaN        NaN         NaN                 NaN  6500.000
# 1869             NaN        NaN         NaN                 NaN     5.187
# 1881             NaN        NaN         NaN                 NaN     0.015
# 1882             NaN        NaN         NaN                 NaN    33.000
# 1892             NaN        NaN         NaN                 NaN     0.180
#
#                                               rawSmiles  \
# 1          CN(CCOc1ccc(C[C@@H]2SC(=O)NC2=O)cc1)c1ccccn1
# 2          CN(CCOc1ccc(C[C@@H]2SC(=O)NC2=O)cc1)c1ccccn1
# 3          CN(CCOc1ccc(C[C@@H]2SC(=O)NC2=O)cc1)c1ccccn1
# 4     Cc1oc(-c2ccc(C(F)(F)F)cc2)nc1Cn1ccc2cc(C[C@@H]...
# 8     Cc1c(C)n(Cc2ccc(-c3ccccc3C(=O)O)cc2)c2ccc(C(=O...
# ...                                                 ...
# 1868  Cc1ccc(Cn2nc(CCCc3ccc(OC(C)(C)C(=O)O)cc3)nc2O)cc1
# 1869  Cc1ccc(Cn2nc(CCCc3ccc(OC(C)(C)C(=O)O)cc3)nc2O)cc1
# 1881  Cc1c(C)n(Cc2ccc(-c3ccccc3C(=O)O)cc2)c2ccc(C(=O...
# 1882  Cc1c(C)n(Cc2ccc(-c3ccccc3C(=O)O)cc2)c2ccc(C(=O...
# 1892  CCCc1cc(C2CCC(O)CC2)ccc1OCCCOc1cccc(C2OC(=O)NC...
#
#                                      preprocessedSmiles  y_true_label
# 1             CN(CCOc1ccc(Cc2sc(=O)[nH]c2O)cc1)c1ccccn1             1
# 2             CN(CCOc1ccc(Cc2sc(=O)[nH]c2O)cc1)c1ccccn1             1
# 3             CN(CCOc1ccc(Cc2sc(=O)[nH]c2O)cc1)c1ccccn1             1
# 4     Cc1oc(-c2ccc(C(F)(F)F)cc2)nc1Cn1ccc2cc(CC(OC(C...             1
# 8     Cc1c(C)n(Cc2ccc(-c3ccccc3C(=O)O)cc2)c2ccc(C(=O...             1
# ...                                                 ...           ...
# 1868  Cc1ccc(Cn2[nH]c(CCCc3ccc(OC(C)(C)C(=O)O)cc3)nc...             0
# 1869  Cc1ccc(Cn2[nH]c(CCCc3ccc(OC(C)(C)C(=O)O)cc3)nc...             0
# 1881  Cc1c(C)n(Cc2ccc(-c3ccccc3C(=O)O)cc2)c2ccc(C(=O...             1
# 1882  Cc1c(C)n(Cc2ccc(-c3ccccc3C(=O)O)cc2)c2ccc(C(=O...             1
# 1892  CCCc1cc(C2CCC(O)CC2)ccc1OCCCOc1cccc(-c2oc(=O)[...             1
#
# [854 rows x 51 columns]

# %%
groups = duplicates_df.groupby('preprocessedSmiles')
id_toremove = []
for name, group in groups:
    # Check if all values in 'y_true_label' are the same within the group
    if not group['y_true_label'].nunique() == 1:
        # Print out 'Molecule ChEMBL ID' for all entries in the group
        print(f"Different activity classifications found for {name}:")
        for chembl_id in group['Molecule ChEMBL ID']:
            print(chembl_id)
            id_toremove.append(chembl_id)
# Out:
# Different activity classifications found for C=C(OC(C)=O)c1c(C(=O)OC)cc2c(O)c3c(c(O)cc4cc(C)c(Cl)c(OC)c43)c(O)c2c1O:
# CHEMBL254814
# CHEMBL254814
# Different activity classifications found for C=C1OC(=O)c2cc3c(O)c4c(c(O)cc5cc(C)c(Cl)c(OC)c54)c(O)c3c(O)c21:
# CHEMBL400132
# CHEMBL400132
# Different activity classifications found for C=Cc1c(C(=O)OC)cc2c(O)c3c(c(O)cc4cc(C)c(Cl)c(OC)c43)c(O)c2c1O:
# CHEMBL253120
# CHEMBL253120
# Different activity classifications found for CC1(C(=O)O)CCc2ccc(OCCCOc3ccc(Oc4ccccc4)cc3Cl)cc2O1:
# CHEMBL111480
# CHEMBL109638
# CHEMBL112790
# Different activity classifications found for CCC1(C(=O)O)CCc2ccc(OCCCOc3ccc(Oc4ccc(F)cc4)cc3Cl)cc2O1:
# CHEMBL109241
# CHEMBL112725
# CHEMBL112725
# Different activity classifications found for CCCCCCCCOc1ccc(C(=O)NC(C(=O)O)C(C)C)cc1:
# CHEMBL4743677
# CHEMBL4743677
# Different activity classifications found for CCCCNC(=O)NS(=O)(=O)c1ccc(NC(=O)Cn2c(=O)c(C)nc3ccccc32)cc1:
# CHEMBL3959627
# CHEMBL3959627
# Different activity classifications found for CCCCNC(=S)NS(=O)(=O)c1ccc(NC(=O)Cn2c(=O)c(C)nc3ccccc32)cc1:
# CHEMBL3943220
# CHEMBL3943220
# Different activity classifications found for CCCc1cc(C(=O)CC)cc(CCC)c1OC(C(=O)O)c1ccc(C(C)C)cc1:
# CHEMBL187557
# CHEMBL434935
# Different activity classifications found for CCOC(=O)N1CC(CC(=O)O)C(c2cccc(OCCc3nc(-c4ccccc4)oc3C)c2)C1:
# CHEMBL3398432
# CHEMBL3398430
# Different activity classifications found for CCOC(=O)N1CC(CCc2ccc(OCCc3nc(-c4ccccc4)oc3C)cc2)C(C(=O)O)C1:
# CHEMBL3398458
# CHEMBL3398460
# Different activity classifications found for CCOC(Cc1ccc(OCCc2nc(-c3ccccc3)oc2C)c2ccsc12)C(=O)O:
# CHEMBL485537
# CHEMBL519153
# CHEMBL484962
# Different activity classifications found for CCc1ccc(CCOc2ccc(Cc3sc(=O)[nH]c3O)cc2)nc1:
# CHEMBL595
# CHEMBL595
# CHEMBL595
# CHEMBL595
# CHEMBL595
# CHEMBL595
# CHEMBL595
# CHEMBL595
# Different activity classifications found for CCc1ccc(OC(C)CCOc2ccc(CCC(=O)O)c(C)c2)c(C(=O)c2ccccc2)c1:
# CHEMBL212911
# CHEMBL212911
# CHEMBL212911
# CHEMBL212911
# CHEMBL215126
# CHEMBL378068
# Different activity classifications found for CN(CCOc1ccc(Cc2sc(=O)[nH]c2O)cc1)c1ccccn1:
# CHEMBL121106
# CHEMBL121106
# CHEMBL121106
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL121
# CHEMBL333304
# CHEMBL333304
# Different activity classifications found for COC(Cc1ccc(OCCc2nc(-c3ccccc3)oc2C)c2ccccc12)C(=O)O:
# CHEMBL521131
# CHEMBL484329
# Different activity classifications found for COC(Cc1ccc(OCCc2nc(-c3ccccc3)oc2C)c2ccsc12)C(=O)O:
# CHEMBL482993
# CHEMBL519032
# CHEMBL519504
# Different activity classifications found for COc1ccc(N2C(=O)C(Cc3ccc(OCCc4nc(-c5ccccc5)oc4C)cc3)C2C(=O)O)cc1:
# CHEMBL272774
# CHEMBL411118
# Different activity classifications found for COc1ccc(N2C(=O)C(Cc3cccc(OCCc4nc(-c5ccccc5)oc4C)c3)C2C(=O)O)cc1:
# CHEMBL271240
# CHEMBL403847
# CHEMBL257891
# Different activity classifications found for COc1ccc(OC(=O)N(CC(=O)O)Cc2ccc(OCCc3nc(-c4ccccc4)oc3C)cc2)cc1:
# CHEMBL557580
# CHEMBL557580
# CHEMBL186179
# CHEMBL186179
# CHEMBL186179
# Different activity classifications found for Cc1c(C)c2c(c(C)c1O)CCC(C)(COc1ccc(Cc3sc(=O)[nH]c3O)cc1)O2:
# CHEMBL408
# CHEMBL408
# CHEMBL408
# CHEMBL408
# CHEMBL408
# CHEMBL408
# Different activity classifications found for Cc1nc2ccccc2n(CC(=O)Nc2ccc(S(=O)(=O)NC(=O)NC3CCCCC3)cc2)c1=O:
# CHEMBL3899514
# CHEMBL3899514
# Different activity classifications found for Cc1nc2ccccc2n(CC(=O)Nc2ccc(S(=O)(=O)NC(=S)NC3CCCCC3)cc2)c1=O:
# CHEMBL3915254
# CHEMBL3915254
# Different activity classifications found for Cc1oc(-c2ccccc2)nc1CC=Cc1ccc(CC(C(=O)O)n2cccc2)cc1:
# CHEMBL477094
# CHEMBL479002
# Different activity classifications found for Cc1oc(-c2ccccc2)nc1CCCc1ccc(CC(C(=O)O)n2cccc2)cc1:
# CHEMBL477095
# CHEMBL477095
# CHEMBL478334
# Different activity classifications found for Cc1oc(-c2ccccc2)nc1CCCc1ccc(CC(C(=O)O)n2cccn2)cc1:
# CHEMBL596544
# CHEMBL593801
# CHEMBL605088
# Different activity classifications found for Cc1oc(-c2ccccc2)nc1CCOc1ccc(CC2C(=O)N(c3ccc(C(C)(C)C)cc3)C2C(=O)O)cc1:
# CHEMBL256468
# CHEMBL404451
# Different activity classifications found for Cc1oc(-c2ccccc2)nc1CCOc1ccc(CC2CN(c3nccc(C(F)(F)F)n3)CC2C(=O)O)cc1:
# CHEMBL3398452
# CHEMBL3398450
# CHEMBL255930
# CHEMBL255930
# CHEMBL3398451
# Different activity classifications found for Cc1oc(-c2ccccc2)nc1CCOc1cccc(C2CN(C(=O)Oc3ccccc3)CC2CC(=O)O)c1:
# CHEMBL3398431
# CHEMBL3398433
# Different activity classifications found for Cc1oc(-c2ccccc2)nc1CCOc1cccc(C=C2CN(C(=O)OCC(C)C)CCC2C(=O)O)c1:
# CHEMBL256134
# CHEMBL256358
# Different activity classifications found for Cc1oc(-c2ccccc2)nc1CCOc1cccc(CC2CN(C(=O)Oc3ccccc3)CC2C(=O)O)c1:
# CHEMBL3398441
# CHEMBL3398439
# CHEMBL3398438
# CHEMBL3398438
# Different activity classifications found for O=C(O)c1ccc(-c2nn(C(=O)c3c(Cl)cccc3C(F)(F)F)c3ccccc23)cc1:
# CHEMBL3598140
# CHEMBL3598140
# CHEMBL3598140
# CHEMBL3598140

# %%
print(len(id_toremove))
# Out:
# 145

# %%
print(len(set(id_toremove)))
# Out:
# 63

# %%
# Drop the rows involved in the printed chembl_ids
for i in set(id_toremove):
    preprocessed_df = preprocessed_df[preprocessed_df['Molecule ChEMBL ID'] != i]

# %%
preprocessed_df
# Out:
#      Molecule ChEMBL ID  Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0          CHEMBL111271            NaN                 NaN            508.59
# 4         CHEMBL2037081            NaN                 NaN            486.49
# 5         CHEMBL3695875            NaN                 NaN            508.67
# 6         CHEMBL3695892            NaN                 NaN            527.50
# 7         CHEMBL3695898            NaN                 NaN            506.62
# ...                 ...            ...                 ...               ...
# 1898          CHEMBL150     KAEMPFEROL                 NaN            286.24
# 1899       CHEMBL379064   ISORHAMNETIN                 NaN            316.26
# 1900        CHEMBL82293  PALMITIC ACID                -1.0            256.43
# 1901         CHEMBL8659     OLEIC ACID                 2.0            282.47
# 1902      CHEMBL1173474   BEHENIC ACID                 NaN            340.59
#
#       #RO5 Violations  AlogP     Compound Key  \
# 0                   2   6.98               25
# 4                   1   6.09               70
# 5                   2   8.62       BDBM147320
# 6                   2   8.77       BDBM147337
# 7                   2   7.61       BDBM147343
# ...               ...    ...              ...
# 1898                0   2.28               20
# 1899                0   2.29  1; Isorhamnetin
# 1900                1   5.55                4
# 1901                1   6.11                9
# 1902                1   7.89                7
#
#                                                  Smiles Standard Type  \
# 0     CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1ccc2c(c1)OC(CC...          IC50
# 4     Cc1oc(-c2ccc(C(F)(F)F)cc2)nc1Cn1ccc2cc(C[C@@H]...          IC50
# 5     Cc1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2ccc(C(=O)N[C@@...          IC50
# 6     Cc1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2ccc(C(=O)N[C@H...          IC50
# 7     COc1c(F)cccc1[C@H](C)NC(=O)c1ccc2c(c1)c(C)c(C)...          IC50
# ...                                                 ...           ...
# 1898            O=c1c(O)c(-c2ccc(O)cc2)oc2cc(O)cc(O)c12          IC50
# 1899            COc1cc(-c2oc3cc(O)cc(O)c3c(=O)c2O)ccc1O          IC50
# 1900                              CCCCCCCCCCCCCCCC(=O)O          IC50
# 1901                         CCCCCCCC/C=C\CCCCCCCC(=O)O          IC50
# 1902                        CCCCCCCCCCCCCCCCCCCCCC(=O)O          IC50
#
#      Standard Relation  ...  Document Journal Document Year  Cell ChEMBL ID  \
# 0                  '='  ...        J Med Chem        2004.0             NaN
# 4                  '='  ...   Bioorg Med Chem        2012.0             NaN
# 5                  '='  ...               NaN        2015.0             NaN
# 6                  '='  ...               NaN        2015.0             NaN
# 7                  '='  ...               NaN        2015.0             NaN
# ...                ...  ...               ...           ...             ...
# 1898               '='  ...    Eur J Med Chem        2021.0             NaN
# 1899               '='  ...    Eur J Med Chem        2021.0             NaN
# 1900               '='  ...      Med Chem Res        2013.0             NaN
# 1901               '='  ...      Med Chem Res        2013.0             NaN
# 1902               '='  ...      Med Chem Res        2013.0             NaN
#
#      Properties Action Type Standard Text Value    Value  \
# 0           NaN         NaN                 NaN    1.200
# 4           NaN         NaN                 NaN    6.857
# 5           NaN         NaN                 NaN  256.000
# 6           NaN         NaN                 NaN    5.000
# 7           NaN         NaN                 NaN   21.000
# ...         ...         ...                 ...      ...
# 1898        NaN     AGONIST                 NaN   23.100
# 1899        NaN  ANTAGONIST                 NaN    3.500
# 1900        NaN         NaN                 NaN   30.000
# 1901        NaN         NaN                 NaN    4.100
# 1902        NaN         NaN                 NaN   30.000
#
#                                               rawSmiles  \
# 0     CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1ccc2c(c1)OC(CC...
# 4     Cc1oc(-c2ccc(C(F)(F)F)cc2)nc1Cn1ccc2cc(C[C@@H]...
# 5     Cc1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2ccc(C(=O)N[C@@...
# 6     Cc1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2ccc(C(=O)N[C@H...
# 7     COc1c(F)cccc1[C@H](C)NC(=O)c1ccc2c(c1)c(C)c(C)...
# ...                                                 ...
# 1898            O=c1c(O)c(-c2ccc(O)cc2)oc2cc(O)cc(O)c12
# 1899            COc1cc(-c2oc3cc(O)cc(O)c3c(=O)c2O)ccc1O
# 1900                              CCCCCCCCCCCCCCCC(=O)O
# 1901                         CCCCCCCC/C=C\CCCCCCCC(=O)O
# 1902                        CCCCCCCCCCCCCCCCCCCCCC(=O)O
#
#                                      preprocessedSmiles  y_true_label
# 0     CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1ccc2c(c1)OC(CC...             0
# 4     Cc1oc(-c2ccc(C(F)(F)F)cc2)nc1Cn1ccc2cc(CC(OC(C...             1
# 5     Cc1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2ccc(C(=O)NC(C)...             1
# 6     Cc1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2ccc(C(=O)NC(C)...             1
# 7     COc1c(F)cccc1C(C)NC(=O)c1ccc2c(c1)c(C)c(C)n2Cc...             1
# ...                                                 ...           ...
# 1898            O=c1c(O)c(-c2ccc(O)cc2)oc2cc(O)cc(O)c12             0
# 1899            COc1cc(-c2oc3cc(O)cc(O)c3c(=O)c2O)ccc1O             0
# 1900                              CCCCCCCCCCCCCCCC(=O)O             0
# 1901                           CCCCCCCCC=CCCCCCCCC(=O)O             0
# 1902                        CCCCCCCCCCCCCCCCCCCCCC(=O)O             0
#
# [1755 rows x 51 columns]

# %%
preprocessed_df.drop_duplicates('preprocessedSmiles',inplace=True)
preprocessed_df
# Out:
#      Molecule ChEMBL ID  Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0          CHEMBL111271            NaN                 NaN            508.59
# 4         CHEMBL2037081            NaN                 NaN            486.49
# 5         CHEMBL3695875            NaN                 NaN            508.67
# 6         CHEMBL3695892            NaN                 NaN            527.50
# 7         CHEMBL3695898            NaN                 NaN            506.62
# ...                 ...            ...                 ...               ...
# 1898          CHEMBL150     KAEMPFEROL                 NaN            286.24
# 1899       CHEMBL379064   ISORHAMNETIN                 NaN            316.26
# 1900        CHEMBL82293  PALMITIC ACID                -1.0            256.43
# 1901         CHEMBL8659     OLEIC ACID                 2.0            282.47
# 1902      CHEMBL1173474   BEHENIC ACID                 NaN            340.59
#
#       #RO5 Violations  AlogP     Compound Key  \
# 0                   2   6.98               25
# 4                   1   6.09               70
# 5                   2   8.62       BDBM147320
# 6                   2   8.77       BDBM147337
# 7                   2   7.61       BDBM147343
# ...               ...    ...              ...
# 1898                0   2.28               20
# 1899                0   2.29  1; Isorhamnetin
# 1900                1   5.55                4
# 1901                1   6.11                9
# 1902                1   7.89                7
#
#                                                  Smiles Standard Type  \
# 0     CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1ccc2c(c1)OC(CC...          IC50
# 4     Cc1oc(-c2ccc(C(F)(F)F)cc2)nc1Cn1ccc2cc(C[C@@H]...          IC50
# 5     Cc1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2ccc(C(=O)N[C@@...          IC50
# 6     Cc1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2ccc(C(=O)N[C@H...          IC50
# 7     COc1c(F)cccc1[C@H](C)NC(=O)c1ccc2c(c1)c(C)c(C)...          IC50
# ...                                                 ...           ...
# 1898            O=c1c(O)c(-c2ccc(O)cc2)oc2cc(O)cc(O)c12          IC50
# 1899            COc1cc(-c2oc3cc(O)cc(O)c3c(=O)c2O)ccc1O          IC50
# 1900                              CCCCCCCCCCCCCCCC(=O)O          IC50
# 1901                         CCCCCCCC/C=C\CCCCCCCC(=O)O          IC50
# 1902                        CCCCCCCCCCCCCCCCCCCCCC(=O)O          IC50
#
#      Standard Relation  ...  Document Journal Document Year  Cell ChEMBL ID  \
# 0                  '='  ...        J Med Chem        2004.0             NaN
# 4                  '='  ...   Bioorg Med Chem        2012.0             NaN
# 5                  '='  ...               NaN        2015.0             NaN
# 6                  '='  ...               NaN        2015.0             NaN
# 7                  '='  ...               NaN        2015.0             NaN
# ...                ...  ...               ...           ...             ...
# 1898               '='  ...    Eur J Med Chem        2021.0             NaN
# 1899               '='  ...    Eur J Med Chem        2021.0             NaN
# 1900               '='  ...      Med Chem Res        2013.0             NaN
# 1901               '='  ...      Med Chem Res        2013.0             NaN
# 1902               '='  ...      Med Chem Res        2013.0             NaN
#
#      Properties Action Type Standard Text Value    Value  \
# 0           NaN         NaN                 NaN    1.200
# 4           NaN         NaN                 NaN    6.857
# 5           NaN         NaN                 NaN  256.000
# 6           NaN         NaN                 NaN    5.000
# 7           NaN         NaN                 NaN   21.000
# ...         ...         ...                 ...      ...
# 1898        NaN     AGONIST                 NaN   23.100
# 1899        NaN  ANTAGONIST                 NaN    3.500
# 1900        NaN         NaN                 NaN   30.000
# 1901        NaN         NaN                 NaN    4.100
# 1902        NaN         NaN                 NaN   30.000
#
#                                               rawSmiles  \
# 0     CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1ccc2c(c1)OC(CC...
# 4     Cc1oc(-c2ccc(C(F)(F)F)cc2)nc1Cn1ccc2cc(C[C@@H]...
# 5     Cc1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2ccc(C(=O)N[C@@...
# 6     Cc1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2ccc(C(=O)N[C@H...
# 7     COc1c(F)cccc1[C@H](C)NC(=O)c1ccc2c(c1)c(C)c(C)...
# ...                                                 ...
# 1898            O=c1c(O)c(-c2ccc(O)cc2)oc2cc(O)cc(O)c12
# 1899            COc1cc(-c2oc3cc(O)cc(O)c3c(=O)c2O)ccc1O
# 1900                              CCCCCCCCCCCCCCCC(=O)O
# 1901                         CCCCCCCC/C=C\CCCCCCCC(=O)O
# 1902                        CCCCCCCCCCCCCCCCCCCCCC(=O)O
#
#                                      preprocessedSmiles  y_true_label
# 0     CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1ccc2c(c1)OC(CC...             0
# 4     Cc1oc(-c2ccc(C(F)(F)F)cc2)nc1Cn1ccc2cc(CC(OC(C...             1
# 5     Cc1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2ccc(C(=O)NC(C)...             1
# 6     Cc1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2ccc(C(=O)NC(C)...             1
# 7     COc1c(F)cccc1C(C)NC(=O)c1ccc2c(c1)c(C)c(C)n2Cc...             1
# ...                                                 ...           ...
# 1898            O=c1c(O)c(-c2ccc(O)cc2)oc2cc(O)cc(O)c12             0
# 1899            COc1cc(-c2oc3cc(O)cc(O)c3c(=O)c2O)ccc1O             0
# 1900                              CCCCCCCCCCCCCCCC(=O)O             0
# 1901                           CCCCCCCCC=CCCCCCCCC(=O)O             0
# 1902                        CCCCCCCCCCCCCCCCCCCCCC(=O)O             0
#
# [1350 rows x 51 columns]

# %%
# Check for duplicates in 'preprocessedSmiles'
duplicates = preprocessed_df.duplicated(subset='preprocessedSmiles', keep=False)

# Show rows where 'preprocessedSmiles' is duplicated
duplicate_rows = preprocessed_df[duplicates]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Molecule ChEMBL ID, Molecule Name, Molecule Max Phase, Molecular Weight, #RO5 Violations, AlogP, Compound Key, Smiles, Standard Type, Standard Relation, Standard Value, Standard Units, pChEMBL Value, Data Validity Comment, Comment, Uo Units, Ligand Efficiency BEI, Ligand Efficiency LE, Ligand Efficiency LLE, Ligand Efficiency SEI, Potential Duplicate, Assay ChEMBL ID, Assay Description, Assay Type, BAO Format ID, BAO Label, Assay Organism, Assay Tissue ChEMBL ID, Assay Tissue Name, Assay Cell Type, Assay Subcellular Fraction, Assay Parameters, Assay Variant Accession, Assay Variant Mutation, Target ChEMBL ID, Target Name, Target Organism, Target Type, Document ChEMBL ID, Source ID, Source Description, Document Journal, Document Year, Cell ChEMBL ID, Properties, Action Type, Standard Text Value, Value, rawSmiles, preprocessedSmiles, y_true_label]
# Index: []
#
# [0 rows x 51 columns]

# %%
len(preprocessed_df[preprocessed_df['pChEMBL Value']>=6]),len(preprocessed_df[preprocessed_df['pChEMBL Value']<6])
# Out:
# (870, 480)

# %%
preprocessed_df_useful = preprocessed_df[['preprocessedSmiles','Molecule ChEMBL ID', 'y_true_label']]
preprocessed_df_useful
# Out:
#                                      preprocessedSmiles Molecule ChEMBL ID  \
# 0     CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1ccc2c(c1)OC(CC...       CHEMBL111271
# 4     Cc1oc(-c2ccc(C(F)(F)F)cc2)nc1Cn1ccc2cc(CC(OC(C...      CHEMBL2037081
# 5     Cc1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2ccc(C(=O)NC(C)...      CHEMBL3695875
# 6     Cc1c(C)n(Cc2ccc(-c3ccccc3)cc2)c2ccc(C(=O)NC(C)...      CHEMBL3695892
# 7     COc1c(F)cccc1C(C)NC(=O)c1ccc2c(c1)c(C)c(C)n2Cc...      CHEMBL3695898
# ...                                                 ...                ...
# 1898            O=c1c(O)c(-c2ccc(O)cc2)oc2cc(O)cc(O)c12          CHEMBL150
# 1899            COc1cc(-c2oc3cc(O)cc(O)c3c(=O)c2O)ccc1O       CHEMBL379064
# 1900                              CCCCCCCCCCCCCCCC(=O)O        CHEMBL82293
# 1901                           CCCCCCCCC=CCCCCCCCC(=O)O         CHEMBL8659
# 1902                        CCCCCCCCCCCCCCCCCCCCCC(=O)O      CHEMBL1173474
#
#      y_true_label
# 0               0
# 4               1
# 5               1
# 6               1
# 7               1
# ...           ...
# 1898            0
# 1899            0
# 1900            0
# 1901            0
# 1902            0
#
# [1350 rows x 3 columns]

# %%
#save data to csv
preprocessed_df_useful.to_csv('./data_sets/ppar_gamma_preprocessed.csv', index=False, sep=';')
