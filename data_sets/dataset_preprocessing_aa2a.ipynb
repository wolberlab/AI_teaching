# %%
import logging

# Disable RDKit logging
logger = logging.getLogger('rdkit')
logger.disabled = True
import rdkit
print(rdkit.__version__)
from rdkit import Chem
import numpy as np
import pandas as pd
from rdkit.Chem import AllChem, PandasTools
# Out:
# 2021.03.2

# %%
'''
The activity data (IC50) of compounds tested on PPAR_gamma (homo sapiens) were downloaded from ChEMBL (CHEMBL251). 

'''
dfic50 = pd.read_csv('./data_sets/aa2a_ic50.csv', delimiter=';')

# %%
len(dfic50)
# Out:
# 1604

# %%
dfic50.dropna(subset = ['Smiles'],inplace=True)
dfic50["Standard Units"].unique(), dfic50['Standard Relation'].unique()
# Out:
# (array([nan, 'nM'], dtype=object),
#  array([nan, "'='", "'>'", "'>='", "'<'"], dtype=object))

# %%
dfic50_1 = dfic50[dfic50['Standard Relation']=="'='"]
dfic50_2 = dfic50.loc[(dfic50['Standard Relation']=="'>'")|(dfic50['Standard Relation']=="'>='")]
dfic50_3 = dfic50[dfic50['Standard Relation'].isna()]
len(dfic50_1), len(dfic50_2), len(dfic50_3)
# Out:
# (582, 142, 842)

# %%
#Only the compounds with IC50 tested and pChEMBL values calculated were selected for further processing and analysis. 
dfic50_1.dropna(subset = ['pChEMBL Value'],inplace=True)
len(dfic50_1)
# Out:
# /tmp/ipykernel_1532554/2328096240.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfic50_1.dropna(subset = ['pChEMBL Value'],inplace=True)
# 574

# %%
dfic50_1
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 2          CHEMBL123195           NaN                 NaN            293.33
# 3           CHEMBL81863           NaN                 NaN            329.41
# 10          CHEMBL21572           NaN                 NaN            463.48
# 11        CHEMBL1081160           NaN                 NaN            395.51
# 15        CHEMBL1077750           NaN                 NaN            288.40
# ...                 ...           ...                 ...               ...
# 1596       CHEMBL113142     ZM-241385                 NaN            337.34
# 1597      CHEMBL4849795           NaN                 NaN            274.33
# 1598      CHEMBL3694769       PBF-509                 1.0            306.13
# 1602      CHEMBL4522981           NaN                 NaN            433.45
# 1603       CHEMBL113142     ZM-241385                 NaN            337.34
#
#       #RO5 Violations  AlogP  Compound Key  \
# 2                 0.0   2.41            13
# 3                 0.0   4.25            4g
# 10                1.0   2.90            49
# 11                0.0   4.06  BDBM50310925
# 15                0.0   3.85             5
# ...               ...    ...           ...
# 1596              0.0   1.72      ZM241385
# 1597              0.0   3.06            27
# 1598              0.0   1.19   40; PBF-509
# 1602              0.0   2.10    8; BAY-545
# 1603              0.0   1.72     ZM-241385
#
#                                                  Smiles Standard Type  \
# 2                  CCCCc1nc2[nH]cnc2c2nc(-c3cccnc3)nn12          IC50
# 3             Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C          IC50
# 10    CSc1c2c(nc(NC(=O)Cc3ccc4c(c3)OCO4)n3nc(-c4ccco...          IC50
# 11         CN(C)c1cc2nc(NCc3cccnc3)nc(C(=O)c3cccs3)c2s1          IC50
# 15                     CCc1nc(C(=O)c2ccc(C)s2)c2sccc2n1          IC50
# ...                                                 ...           ...
# 1596           Nc1nc(NCCc2ccc(O)cc2)nc2nc(-c3ccco3)nn12          IC50
# 1597                    Nc1nc(Cc2ccccc2)cn2c1nc1ccccc12          IC50
# 1598                    Nc1nc(-n2cccn2)nc(-n2cccn2)c1Br          IC50
# 1602  CCn1c(=O)c2c(C)c(C(=O)N3CCC(O)CC3)sc2n(CCC(F)(...          IC50
# 1603           Nc1nc(NCCc2ccc(O)cc2)nc2nc(-c3ccco3)nn12          IC50
#
#      Standard Relation  ...  Document ChEMBL ID Source ID  \
# 2                  '='  ...       CHEMBL1135548         1
# 3                  '='  ...       CHEMBL1131846         1
# 10                 '='  ...       CHEMBL1136743         1
# 11                 '='  ...       CHEMBL3886219        37
# 15                 '='  ...       CHEMBL1154258         1
# ...                ...  ...                 ...       ...
# 1596               '='  ...       CHEMBL5126601         1
# 1597               '='  ...       CHEMBL4813923         1
# 1598               '='  ...       CHEMBL4699449         1
# 1602               '='  ...       CHEMBL4422615         1
# 1603               '='  ...       CHEMBL4251607         1
#
#                      Source Description      Document Journal Document Year  \
# 2                 Scientific Literature            J Med Chem        2002.0
# 3                 Scientific Literature  Bioorg Med Chem Lett        1999.0
# 10                Scientific Literature            J Med Chem        2003.0
# 11    BindingDB Patent Bioactivity Data                   NaN        2015.0
# 15                Scientific Literature  Bioorg Med Chem Lett        2009.0
# ...                                 ...                   ...           ...
# 1596              Scientific Literature     ACS Med Chem Lett        2022.0
# 1597              Scientific Literature        Eur J Med Chem        2021.0
# 1598              Scientific Literature            J Med Chem        2020.0
# 1602              Scientific Literature        Eur J Med Chem        2019.0
# 1603              Scientific Literature        Eur J Med Chem        2018.0
#
#      Cell ChEMBL ID        Properties  Action Type  Standard Text Value  \
# 2     CHEMBL3307715               NaN          NaN                  NaN
# 3               NaN               NaN          NaN                  NaN
# 10              NaN               NaN          NaN                  NaN
# 11              NaN               NaN          NaN                  NaN
# 15    CHEMBL3307512               NaN          NaN                  NaN
# ...             ...               ...          ...                  ...
# 1596            NaN               NaN   ANTAGONIST                  NaN
# 1597            NaN  TIME = 0.6667 hr   ANTAGONIST                  NaN
# 1598            NaN     TIME = 0.5 hr   ANTAGONIST                  NaN
# 1602  CHEMBL3308072               NaN          NaN                  NaN
# 1603            NaN               NaN          NaN                  NaN
#
#         Value
# 2      900.00
# 3     1711.00
# 10      21.50
# 11     318.30
# 15    3852.00
# ...       ...
# 1596     8.82
# 1597    31.00
# 1598    25.00
# 1602   820.00
# 1603    80.80
#
# [574 rows x 48 columns]

# %%
len(dfic50_1[dfic50_1['pChEMBL Value']>=6]),len(dfic50_1[dfic50_1['pChEMBL Value']<6])
# Out:
# (434, 140)

# %%
import sys
sys.path.append('/home/sliu/cyp_related_coding/CYP19_inhibitor_screening/')
'''
The following function used for molecule preprocessing is from 'RingSySTEMS' project: https://github.com/anya-chen/RingSystems/tree/master/Preprocessing/src
'''
from src import MoleculePreprocessor
from src.MoleculePreprocessor import MoleculePreprocessor
from src.MoleculePreprocessorExtended import MoleculePreprocessorExtended

# %%
moleculesProcessed = MoleculePreprocessorExtended.init_with_smiles(list(dfic50_1.Smiles))

# %%
from rdkit import RDLogger
moleculesProcessed.csp_wash()

# %%
preprocessedSmilesDict = moleculesProcessed.get_rawsmiles_smiles_dict()

# %%
preprocessedSmiles_df = pd.DataFrame(list(preprocessedSmilesDict.items()), columns=['rawSmiles','preprocessedSmiles'])

# %%
preprocessed_df = pd.merge(dfic50_1, preprocessedSmiles_df, 
                           left_on='Smiles', right_on='rawSmiles')

# %%
preprocessed_df.dropna(subset=['preprocessedSmiles'],inplace=True)

# %%
preprocessed_df = preprocessed_df[preprocessed_df['preprocessedSmiles']!='']

# %%
len(preprocessed_df)
# Out:
# 565

# %%
# Use the loc method to set the values in the new column based on the values in the existing column
preprocessed_df.loc[preprocessed_df['pChEMBL Value']>=6, 'y_true_label'] = '1'
preprocessed_df.loc[preprocessed_df['pChEMBL Value']<6, 'y_true_label'] = '0'

# %%
def remove_stereochemistry(smiles):
    # Convert the SMILES string to an RDKit molecule object
    mol = Chem.MolFromSmiles(smiles)
    
    # Use the Chem.RemoveStereochemistry function to remove stereo informationz
    Chem.RemoveStereochemistry(mol)
    
    # Convert the molecule back to a SMILES string without stereochemistry
    return Chem.MolToSmiles(mol)

preprocessed_df['preprocessedSmiles'] = preprocessed_df['preprocessedSmiles'].apply(remove_stereochemistry)
preprocessed_df
# Out:
#     Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0         CHEMBL123195           NaN                 NaN            293.33
# 1          CHEMBL81863           NaN                 NaN            329.41
# 2          CHEMBL81863           NaN                 NaN            329.41
# 3          CHEMBL21572           NaN                 NaN            463.48
# 4        CHEMBL1081160           NaN                 NaN            395.51
# ..                 ...           ...                 ...               ...
# 569      CHEMBL5092804           NaN                 NaN            461.53
# 570      CHEMBL5081971           NaN                 NaN            523.60
# 571      CHEMBL5079711           NaN                 NaN            462.51
# 572      CHEMBL1933288           NaN                 NaN            458.57
# 573      CHEMBL4522981           NaN                 NaN            433.45
#
#      #RO5 Violations  AlogP  Compound Key  \
# 0                0.0   2.41            13
# 1                0.0   4.25            4g
# 2                0.0   4.25            4g
# 3                1.0   2.90            49
# 4                0.0   4.06  BDBM50310925
# ..               ...    ...           ...
# 569              0.0   2.17            23
# 570              1.0   3.95            35
# 571              1.0   1.56            37
# 572              0.0   3.89   EUB0000679a
# 573              0.0   2.10    8; BAY-545
#
#                                                 Smiles Standard Type  \
# 0                 CCCCc1nc2[nH]cnc2c2nc(-c3cccnc3)nn12          IC50
# 1            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C          IC50
# 2            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C          IC50
# 3    CSc1c2c(nc(NC(=O)Cc3ccc4c(c3)OCO4)n3nc(-c4ccco...          IC50
# 4         CN(C)c1cc2nc(NCc3cccnc3)nc(C(=O)c3cccs3)c2s1          IC50
# ..                                                 ...           ...
# 569  COc1cccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N...          IC50
# 570  Cc1ccc(-c2nc(N)nc3c2ncc(=O)n3CCN2CCN(c3ccc(Oc4...          IC50
# 571  COc1ccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N)...          IC50
# 572  C[C@@H]1CCNC(=O)c2cc3ccc(C(=O)Nc4nc5ccccc5n4CC...          IC50
# 573  CCn1c(=O)c2c(C)c(C(=O)N3CCC(O)CC3)sc2n(CCC(F)(...          IC50
#
#     Standard Relation  ...      Document Journal Document Year  \
# 0                 '='  ...            J Med Chem        2002.0
# 1                 '='  ...  Bioorg Med Chem Lett        1999.0
# 2                 '='  ...  Bioorg Med Chem Lett        1999.0
# 3                 '='  ...            J Med Chem        2003.0
# 4                 '='  ...                   NaN        2015.0
# ..                ...  ...                   ...           ...
# 569               '='  ...            J Med Chem        2022.0
# 570               '='  ...            J Med Chem        2022.0
# 571               '='  ...            J Med Chem        2022.0
# 572               '='  ...                   NaN        2023.0
# 573               '='  ...        Eur J Med Chem        2019.0
#
#      Cell ChEMBL ID                                         Properties  \
# 0     CHEMBL3307715                                                NaN
# 1               NaN                                                NaN
# 2     CHEMBL3307715                                                NaN
# 3               NaN                                                NaN
# 4               NaN                                                NaN
# ..              ...                                                ...
# 569             NaN                                      TIME = 1.0 hr
# 570             NaN                                      TIME = 1.0 hr
# 571             NaN                                      TIME = 1.0 hr
# 572             NaN  Selectivity number of off-targets = 0.0 None |...
# 573   CHEMBL3308072                                                NaN
#
#     Action Type Standard Text Value   Value  \
# 0           NaN                 NaN   900.0
# 1           NaN                 NaN  1711.0
# 2           NaN                 NaN  2010.0
# 3           NaN                 NaN    21.5
# 4           NaN                 NaN   318.3
# ..          ...                 ...     ...
# 569  ANTAGONIST                 NaN    45.5
# 570  ANTAGONIST                 NaN   604.8
# 571  ANTAGONIST                 NaN   213.0
# 572         NaN                 NaN  1420.0
# 573         NaN                 NaN   820.0
#
#                                              rawSmiles  \
# 0                 CCCCc1nc2[nH]cnc2c2nc(-c3cccnc3)nn12
# 1            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C
# 2            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C
# 3    CSc1c2c(nc(NC(=O)Cc3ccc4c(c3)OCO4)n3nc(-c4ccco...
# 4         CN(C)c1cc2nc(NCc3cccnc3)nc(C(=O)c3cccs3)c2s1
# ..                                                 ...
# 569  COc1cccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N...
# 570  Cc1ccc(-c2nc(N)nc3c2ncc(=O)n3CCN2CCN(c3ccc(Oc4...
# 571  COc1ccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N)...
# 572  C[C@@H]1CCNC(=O)c2cc3ccc(C(=O)Nc4nc5ccccc5n4CC...
# 573  CCn1c(=O)c2c(C)c(C(=O)N3CCC(O)CC3)sc2n(CCC(F)(...
#
#                                     preprocessedSmiles  y_true_label
# 0                 CCCCc1nc2[nH]cnc2c2nc(-c3cccnc3)nn12             1
# 1            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C             0
# 2            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C             0
# 3    CSc1c2c(nc(NC(=O)Cc3ccc4c(c3)OCO4)n3nc(-c4ccco...             1
# 4         CN(C)c1cc2nc(NCc3cccnc3)nc(C(=O)c3cccs3)c2s1             1
# ..                                                 ...           ...
# 569  COc1cccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N...             1
# 570  Cc1ccc(-c2nc(N)nc3c2ncc(=O)n3CCN2CCN(c3ccc(Oc4...             1
# 571  COc1ccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N)...             1
# 572  CC1CCNC(=O)c2cc3ccc(C(=O)Nc4nc5ccccc5n4CCCN(C)...             0
# 573  CCn1c(=O)c2c(C)c(C(=O)N3CCC(O)CC3)sc2n(CCC(F)(...             1
#
# [565 rows x 51 columns]

# %%
duplicates = preprocessed_df.duplicated('preprocessedSmiles', keep=False)

# Filter DataFrame to list duplicates with their information
duplicates_df = preprocessed_df[duplicates]
duplicates_df
# Out:
#     Molecule ChEMBL ID   Molecule Name  Molecule Max Phase  Molecular Weight  \
# 1          CHEMBL81863             NaN                 NaN            329.41
# 2          CHEMBL81863             NaN                 NaN            329.41
# 4        CHEMBL1081160             NaN                 NaN            395.51
# 5        CHEMBL1081160             NaN                 NaN            395.51
# 10       CHEMBL1079893             NaN                 NaN            353.45
# ..                 ...             ...                 ...               ...
# 497      CHEMBL5176737             NaN                 NaN            318.34
# 511      CHEMBL5094102             NaN                 NaN            475.55
# 529       CHEMBL431770  ISTRADEFYLLINE                 4.0            384.44
# 530       CHEMBL431770  ISTRADEFYLLINE                 4.0            384.44
# 563      CHEMBL5203105             NaN                 NaN            391.26
#
#      #RO5 Violations  AlogP  Compound Key  \
# 1                0.0   4.25            4g
# 2                0.0   4.25            4g
# 4                0.0   4.06  BDBM50310925
# 5                0.0   4.06            35
# 10               0.0   3.50            43
# ..               ...    ...           ...
# 497              0.0   1.79           12o
# 511              0.0   2.56            48
# 529              0.0   2.12    2, KW 6002
# 530              0.0   2.12    2, KW 6002
# 563              0.0   1.79      12o 2HCl
#
#                                                 Smiles Standard Type  \
# 1            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C          IC50
# 2            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C          IC50
# 4         CN(C)c1cc2nc(NCc3cccnc3)nc(C(=O)c3cccs3)c2s1          IC50
# 5         CN(C)c1cc2nc(NCc3cccnc3)nc(C(=O)c3cccs3)c2s1          IC50
# 10       C[C@@H](Nc1nc(C(=O)N2CCCC2)c2sccc2n1)c1cccnc1          IC50
# ..                                                 ...           ...
# 497              Nc1nc(C(=O)NCc2ccccn2)cn2c1nc1ccccc12          IC50
# 511  COc1ccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N)...          IC50
# 529  CCn1c(=O)c2c(nc(/C=C/c3ccc(OC)c(OC)c3)n2C)n(CC...          IC50
# 530  CCn1c(=O)c2c(nc(/C=C/c3ccc(OC)c(OC)c3)n2C)n(CC...          IC50
# 563        Cl.Cl.Nc1nc(C(=O)NCc2ccccn2)cn2c1nc1ccccc12          IC50
#
#     Standard Relation  ...      Document Journal Document Year  \
# 1                 '='  ...  Bioorg Med Chem Lett        1999.0
# 2                 '='  ...  Bioorg Med Chem Lett        1999.0
# 4                 '='  ...                   NaN        2015.0
# 5                 '='  ...  Bioorg Med Chem Lett        2009.0
# 10                '='  ...  Bioorg Med Chem Lett        2009.0
# ..                ...  ...                   ...           ...
# 497               '='  ...            J Med Chem        2022.0
# 511               '='  ...            J Med Chem        2022.0
# 529               '='  ...  Bioorg Med Chem Lett        2013.0
# 530               '='  ...  Bioorg Med Chem Lett        2013.0
# 563               '='  ...            J Med Chem        2022.0
#
#      Cell ChEMBL ID     Properties Action Type Standard Text Value    Value  \
# 1               NaN            NaN         NaN                 NaN  1711.00
# 2     CHEMBL3307715            NaN         NaN                 NaN  2010.00
# 4               NaN            NaN         NaN                 NaN   318.30
# 5     CHEMBL3307512            NaN         NaN                 NaN  1417.00
# 10    CHEMBL3307512            NaN         NaN                 NaN  6760.00
# ..              ...            ...         ...                 ...      ...
# 497             NaN  TIME = 0.5 hr  ANTAGONIST                 NaN    69.90
# 511             NaN  TIME = 1.0 hr  ANTAGONIST                 NaN     6.90
# 529   CHEMBL3308072            NaN         NaN                 NaN  5250.00
# 530   CHEMBL3308072            NaN         NaN                 NaN     5.28
# 563             NaN  TIME = 0.5 hr  ANTAGONIST                 NaN    10.50
#
#                                              rawSmiles  \
# 1            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C
# 2            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C
# 4         CN(C)c1cc2nc(NCc3cccnc3)nc(C(=O)c3cccs3)c2s1
# 5         CN(C)c1cc2nc(NCc3cccnc3)nc(C(=O)c3cccs3)c2s1
# 10       C[C@@H](Nc1nc(C(=O)N2CCCC2)c2sccc2n1)c1cccnc1
# ..                                                 ...
# 497              Nc1nc(C(=O)NCc2ccccn2)cn2c1nc1ccccc12
# 511  COc1ccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N)...
# 529  CCn1c(=O)c2c(nc(/C=C/c3ccc(OC)c(OC)c3)n2C)n(CC...
# 530  CCn1c(=O)c2c(nc(/C=C/c3ccc(OC)c(OC)c3)n2C)n(CC...
# 563        Cl.Cl.Nc1nc(C(=O)NCc2ccccn2)cn2c1nc1ccccc12
#
#                                     preprocessedSmiles  y_true_label
# 1            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C             0
# 2            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C             0
# 4         CN(C)c1cc2nc(NCc3cccnc3)nc(C(=O)c3cccs3)c2s1             1
# 5         CN(C)c1cc2nc(NCc3cccnc3)nc(C(=O)c3cccs3)c2s1             0
# 10            CC(Nc1nc(C(=O)N2CCCC2)c2sccc2n1)c1cccnc1             0
# ..                                                 ...           ...
# 497              Nc1nc(C(=O)NCc2ccccn2)cn2c1nc1ccccc12             1
# 511  COc1ccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N)...             1
# 529  CCn1c(=O)c2c(nc(C=Cc3ccc(OC)c(OC)c3)n2C)n(CC)c1=O             0
# 530  CCn1c(=O)c2c(nc(C=Cc3ccc(OC)c(OC)c3)n2C)n(CC)c1=O             0
# 563              Nc1nc(C(=O)NCc2ccccn2)cn2c1nc1ccccc12             1
#
# [202 rows x 51 columns]

# %%
groups = duplicates_df.groupby('preprocessedSmiles')
id_toremove = []
for name, group in groups:
    # Check if all values in 'y_true_label' are the same within the group
    if not group['y_true_label'].nunique() == 1:
        # Print out 'Molecule ChEMBL ID' for all entries in the group
        print(f"Different activity classifications found for {name}:")
        for chembl_id in group['Molecule ChEMBL ID']:
            print(chembl_id)
            id_toremove.append(chembl_id)
# Out:
# Different activity classifications found for CC(Nc1nc(C(=O)N2CCCC2)c2sccc2n1)c1cccnc1:
# CHEMBL1079893
# CHEMBL1082064
# CHEMBL1079894
# Different activity classifications found for CCNc1cc2nc(NCc3cccnc3)nc(C(=O)c3cccs3)c2s1:
# CHEMBL1080421
# CHEMBL1080421
# Different activity classifications found for CN(C)c1cc2nc(NCc3cccnc3)nc(C(=O)c3cccs3)c2s1:
# CHEMBL1081160
# CHEMBL1081160
# Different activity classifications found for Cc1c(C#N)cccc1-c1cc(-c2ccn(Cc3cccc(C(C)(C)O)c3)c(=O)c2)nc(N)n1:
# CHEMBL5424461
# CHEMBL5424461
# CHEMBL5424461
# Different activity classifications found for Cc1ccc(-c2nc(N)nc3c2nnn3Cc2cccc(COC3CCOC3)n2)o1:
# CHEMBL4297184
# CHEMBL4297184
# CHEMBL4297184
# CHEMBL4297184
# CHEMBL4297184
# CHEMBL4297184

# %%
print(len(id_toremove))
# Out:
# 16

# %%
print(len(set(id_toremove)))
# Out:
# 7

# %%
# Drop the rows involved in the printed chembl_ids
for i in set(id_toremove):
    preprocessed_df = preprocessed_df[preprocessed_df['Molecule ChEMBL ID'] != i]

# %%
preprocessed_df
# Out:
#     Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0         CHEMBL123195           NaN                 NaN            293.33
# 1          CHEMBL81863           NaN                 NaN            329.41
# 2          CHEMBL81863           NaN                 NaN            329.41
# 3          CHEMBL21572           NaN                 NaN            463.48
# 6        CHEMBL1077750           NaN                 NaN            288.40
# ..                 ...           ...                 ...               ...
# 569      CHEMBL5092804           NaN                 NaN            461.53
# 570      CHEMBL5081971           NaN                 NaN            523.60
# 571      CHEMBL5079711           NaN                 NaN            462.51
# 572      CHEMBL1933288           NaN                 NaN            458.57
# 573      CHEMBL4522981           NaN                 NaN            433.45
#
#      #RO5 Violations  AlogP Compound Key  \
# 0                0.0   2.41           13
# 1                0.0   4.25           4g
# 2                0.0   4.25           4g
# 3                1.0   2.90           49
# 6                0.0   3.85            5
# ..               ...    ...          ...
# 569              0.0   2.17           23
# 570              1.0   3.95           35
# 571              1.0   1.56           37
# 572              0.0   3.89  EUB0000679a
# 573              0.0   2.10   8; BAY-545
#
#                                                 Smiles Standard Type  \
# 0                 CCCCc1nc2[nH]cnc2c2nc(-c3cccnc3)nn12          IC50
# 1            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C          IC50
# 2            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C          IC50
# 3    CSc1c2c(nc(NC(=O)Cc3ccc4c(c3)OCO4)n3nc(-c4ccco...          IC50
# 6                     CCc1nc(C(=O)c2ccc(C)s2)c2sccc2n1          IC50
# ..                                                 ...           ...
# 569  COc1cccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N...          IC50
# 570  Cc1ccc(-c2nc(N)nc3c2ncc(=O)n3CCN2CCN(c3ccc(Oc4...          IC50
# 571  COc1ccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N)...          IC50
# 572  C[C@@H]1CCNC(=O)c2cc3ccc(C(=O)Nc4nc5ccccc5n4CC...          IC50
# 573  CCn1c(=O)c2c(C)c(C(=O)N3CCC(O)CC3)sc2n(CCC(F)(...          IC50
#
#     Standard Relation  ...      Document Journal Document Year  \
# 0                 '='  ...            J Med Chem        2002.0
# 1                 '='  ...  Bioorg Med Chem Lett        1999.0
# 2                 '='  ...  Bioorg Med Chem Lett        1999.0
# 3                 '='  ...            J Med Chem        2003.0
# 6                 '='  ...  Bioorg Med Chem Lett        2009.0
# ..                ...  ...                   ...           ...
# 569               '='  ...            J Med Chem        2022.0
# 570               '='  ...            J Med Chem        2022.0
# 571               '='  ...            J Med Chem        2022.0
# 572               '='  ...                   NaN        2023.0
# 573               '='  ...        Eur J Med Chem        2019.0
#
#      Cell ChEMBL ID                                         Properties  \
# 0     CHEMBL3307715                                                NaN
# 1               NaN                                                NaN
# 2     CHEMBL3307715                                                NaN
# 3               NaN                                                NaN
# 6     CHEMBL3307512                                                NaN
# ..              ...                                                ...
# 569             NaN                                      TIME = 1.0 hr
# 570             NaN                                      TIME = 1.0 hr
# 571             NaN                                      TIME = 1.0 hr
# 572             NaN  Selectivity number of off-targets = 0.0 None |...
# 573   CHEMBL3308072                                                NaN
#
#     Action Type Standard Text Value   Value  \
# 0           NaN                 NaN   900.0
# 1           NaN                 NaN  1711.0
# 2           NaN                 NaN  2010.0
# 3           NaN                 NaN    21.5
# 6           NaN                 NaN  3852.0
# ..          ...                 ...     ...
# 569  ANTAGONIST                 NaN    45.5
# 570  ANTAGONIST                 NaN   604.8
# 571  ANTAGONIST                 NaN   213.0
# 572         NaN                 NaN  1420.0
# 573         NaN                 NaN   820.0
#
#                                              rawSmiles  \
# 0                 CCCCc1nc2[nH]cnc2c2nc(-c3cccnc3)nn12
# 1            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C
# 2            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C
# 3    CSc1c2c(nc(NC(=O)Cc3ccc4c(c3)OCO4)n3nc(-c4ccco...
# 6                     CCc1nc(C(=O)c2ccc(C)s2)c2sccc2n1
# ..                                                 ...
# 569  COc1cccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N...
# 570  Cc1ccc(-c2nc(N)nc3c2ncc(=O)n3CCN2CCN(c3ccc(Oc4...
# 571  COc1ccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N)...
# 572  C[C@@H]1CCNC(=O)c2cc3ccc(C(=O)Nc4nc5ccccc5n4CC...
# 573  CCn1c(=O)c2c(C)c(C(=O)N3CCC(O)CC3)sc2n(CCC(F)(...
#
#                                     preprocessedSmiles  y_true_label
# 0                 CCCCc1nc2[nH]cnc2c2nc(-c3cccnc3)nn12             1
# 1            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C             0
# 2            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C             0
# 3    CSc1c2c(nc(NC(=O)Cc3ccc4c(c3)OCO4)n3nc(-c4ccco...             1
# 6                     CCc1nc(C(=O)c2ccc(C)s2)c2sccc2n1             0
# ..                                                 ...           ...
# 569  COc1cccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N...             1
# 570  Cc1ccc(-c2nc(N)nc3c2ncc(=O)n3CCN2CCN(c3ccc(Oc4...             1
# 571  COc1ccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N)...             1
# 572  CC1CCNC(=O)c2cc3ccc(C(=O)Nc4nc5ccccc5n4CCCN(C)...             0
# 573  CCn1c(=O)c2c(C)c(C(=O)N3CCC(O)CC3)sc2n(CCC(F)(...             1
#
# [549 rows x 51 columns]

# %%
preprocessed_df.drop_duplicates('preprocessedSmiles',inplace=True)
preprocessed_df
# Out:
#     Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0         CHEMBL123195           NaN                 NaN            293.33
# 1          CHEMBL81863           NaN                 NaN            329.41
# 3          CHEMBL21572           NaN                 NaN            463.48
# 6        CHEMBL1077750           NaN                 NaN            288.40
# 7        CHEMBL1078001           NaN                 NaN            380.45
# ..                 ...           ...                 ...               ...
# 569      CHEMBL5092804           NaN                 NaN            461.53
# 570      CHEMBL5081971           NaN                 NaN            523.60
# 571      CHEMBL5079711           NaN                 NaN            462.51
# 572      CHEMBL1933288           NaN                 NaN            458.57
# 573      CHEMBL4522981           NaN                 NaN            433.45
#
#      #RO5 Violations  AlogP Compound Key  \
# 0                0.0   2.41           13
# 1                0.0   4.25           4g
# 3                1.0   2.90           49
# 6                0.0   3.85            5
# 7                0.0   3.94           14
# ..               ...    ...          ...
# 569              0.0   2.17           23
# 570              1.0   3.95           35
# 571              1.0   1.56           37
# 572              0.0   3.89  EUB0000679a
# 573              0.0   2.10   8; BAY-545
#
#                                                 Smiles Standard Type  \
# 0                 CCCCc1nc2[nH]cnc2c2nc(-c3cccnc3)nn12          IC50
# 1            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C          IC50
# 3    CSc1c2c(nc(NC(=O)Cc3ccc4c(c3)OCO4)n3nc(-c4ccco...          IC50
# 6                     CCc1nc(C(=O)c2ccc(C)s2)c2sccc2n1          IC50
# 7         Cc1ccc(C(=O)c2nc(NC(=O)c3cccnc3)nc3ccsc23)s1          IC50
# ..                                                 ...           ...
# 569  COc1cccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N...          IC50
# 570  Cc1ccc(-c2nc(N)nc3c2ncc(=O)n3CCN2CCN(c3ccc(Oc4...          IC50
# 571  COc1ccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N)...          IC50
# 572  C[C@@H]1CCNC(=O)c2cc3ccc(C(=O)Nc4nc5ccccc5n4CC...          IC50
# 573  CCn1c(=O)c2c(C)c(C(=O)N3CCC(O)CC3)sc2n(CCC(F)(...          IC50
#
#     Standard Relation  ...      Document Journal Document Year  \
# 0                 '='  ...            J Med Chem        2002.0
# 1                 '='  ...  Bioorg Med Chem Lett        1999.0
# 3                 '='  ...            J Med Chem        2003.0
# 6                 '='  ...  Bioorg Med Chem Lett        2009.0
# 7                 '='  ...  Bioorg Med Chem Lett        2009.0
# ..                ...  ...                   ...           ...
# 569               '='  ...            J Med Chem        2022.0
# 570               '='  ...            J Med Chem        2022.0
# 571               '='  ...            J Med Chem        2022.0
# 572               '='  ...                   NaN        2023.0
# 573               '='  ...        Eur J Med Chem        2019.0
#
#      Cell ChEMBL ID                                         Properties  \
# 0     CHEMBL3307715                                                NaN
# 1               NaN                                                NaN
# 3               NaN                                                NaN
# 6     CHEMBL3307512                                                NaN
# 7     CHEMBL3307512                                                NaN
# ..              ...                                                ...
# 569             NaN                                      TIME = 1.0 hr
# 570             NaN                                      TIME = 1.0 hr
# 571             NaN                                      TIME = 1.0 hr
# 572             NaN  Selectivity number of off-targets = 0.0 None |...
# 573   CHEMBL3308072                                                NaN
#
#     Action Type Standard Text Value   Value  \
# 0           NaN                 NaN   900.0
# 1           NaN                 NaN  1711.0
# 3           NaN                 NaN    21.5
# 6           NaN                 NaN  3852.0
# 7           NaN                 NaN   161.0
# ..          ...                 ...     ...
# 569  ANTAGONIST                 NaN    45.5
# 570  ANTAGONIST                 NaN   604.8
# 571  ANTAGONIST                 NaN   213.0
# 572         NaN                 NaN  1420.0
# 573         NaN                 NaN   820.0
#
#                                              rawSmiles  \
# 0                 CCCCc1nc2[nH]cnc2c2nc(-c3cccnc3)nn12
# 1            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C
# 3    CSc1c2c(nc(NC(=O)Cc3ccc4c(c3)OCO4)n3nc(-c4ccco...
# 6                     CCc1nc(C(=O)c2ccc(C)s2)c2sccc2n1
# 7         Cc1ccc(C(=O)c2nc(NC(=O)c3cccnc3)nc3ccsc23)s1
# ..                                                 ...
# 569  COc1cccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N...
# 570  Cc1ccc(-c2nc(N)nc3c2ncc(=O)n3CCN2CCN(c3ccc(Oc4...
# 571  COc1ccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N)...
# 572  C[C@@H]1CCNC(=O)c2cc3ccc(C(=O)Nc4nc5ccccc5n4CC...
# 573  CCn1c(=O)c2c(C)c(C(=O)N3CCC(O)CC3)sc2n(CCC(F)(...
#
#                                     preprocessedSmiles  y_true_label
# 0                 CCCCc1nc2[nH]cnc2c2nc(-c3cccnc3)nn12             1
# 1            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C             0
# 3    CSc1c2c(nc(NC(=O)Cc3ccc4c(c3)OCO4)n3nc(-c4ccco...             1
# 6                     CCc1nc(C(=O)c2ccc(C)s2)c2sccc2n1             0
# 7         Cc1ccc(C(=O)c2nc(NC(=O)c3cccnc3)nc3ccsc23)s1             1
# ..                                                 ...           ...
# 569  COc1cccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N...             1
# 570  Cc1ccc(-c2nc(N)nc3c2ncc(=O)n3CCN2CCN(c3ccc(Oc4...             1
# 571  COc1ccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N)...             1
# 572  CC1CCNC(=O)c2cc3ccc(C(=O)Nc4nc5ccccc5n4CCCN(C)...             0
# 573  CCn1c(=O)c2c(C)c(C(=O)N3CCC(O)CC3)sc2n(CCC(F)(...             1
#
# [443 rows x 51 columns]

# %%
# Check for duplicates in 'preprocessedSmiles'
duplicates = preprocessed_df.duplicated(subset='preprocessedSmiles', keep=False)

# Show rows where 'preprocessedSmiles' is duplicated
duplicate_rows = preprocessed_df[duplicates]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Molecule ChEMBL ID, Molecule Name, Molecule Max Phase, Molecular Weight, #RO5 Violations, AlogP, Compound Key, Smiles, Standard Type, Standard Relation, Standard Value, Standard Units, pChEMBL Value, Data Validity Comment, Comment, Uo Units, Ligand Efficiency BEI, Ligand Efficiency LE, Ligand Efficiency LLE, Ligand Efficiency SEI, Potential Duplicate, Assay ChEMBL ID, Assay Description, Assay Type, BAO Format ID, BAO Label, Assay Organism, Assay Tissue ChEMBL ID, Assay Tissue Name, Assay Cell Type, Assay Subcellular Fraction, Assay Parameters, Assay Variant Accession, Assay Variant Mutation, Target ChEMBL ID, Target Name, Target Organism, Target Type, Document ChEMBL ID, Source ID, Source Description, Document Journal, Document Year, Cell ChEMBL ID, Properties, Action Type, Standard Text Value, Value, rawSmiles, preprocessedSmiles, y_true_label]
# Index: []
#
# [0 rows x 51 columns]

# %%
len(preprocessed_df[preprocessed_df['pChEMBL Value']>=6]),len(preprocessed_df[preprocessed_df['pChEMBL Value']<6])
# Out:
# (334, 109)

# %%
preprocessed_df_useful = preprocessed_df[['preprocessedSmiles','Molecule ChEMBL ID', 'y_true_label']]
preprocessed_df_useful
# Out:
#                                     preprocessedSmiles Molecule ChEMBL ID  \
# 0                 CCCCc1nc2[nH]cnc2c2nc(-c3cccnc3)nn12       CHEMBL123195
# 1            Cc1[nH]c2nc(-c3ccccc3)nc(NCc3ccncc3)c2c1C        CHEMBL81863
# 3    CSc1c2c(nc(NC(=O)Cc3ccc4c(c3)OCO4)n3nc(-c4ccco...        CHEMBL21572
# 6                     CCc1nc(C(=O)c2ccc(C)s2)c2sccc2n1      CHEMBL1077750
# 7         Cc1ccc(C(=O)c2nc(NC(=O)c3cccnc3)nc3ccsc23)s1      CHEMBL1078001
# ..                                                 ...                ...
# 569  COc1cccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N...      CHEMBL5092804
# 570  Cc1ccc(-c2nc(N)nc3c2ncc(=O)n3CCN2CCN(c3ccc(Oc4...      CHEMBL5081971
# 571  COc1ccc(N2CCN(CCn3c(=O)cnc4c(-c5ccc(C)o5)nc(N)...      CHEMBL5079711
# 572  CC1CCNC(=O)c2cc3ccc(C(=O)Nc4nc5ccccc5n4CCCN(C)...      CHEMBL1933288
# 573  CCn1c(=O)c2c(C)c(C(=O)N3CCC(O)CC3)sc2n(CCC(F)(...      CHEMBL4522981
#
#     y_true_label
# 0              1
# 1              0
# 3              1
# 6              0
# 7              1
# ..           ...
# 569            1
# 570            1
# 571            1
# 572            0
# 573            1
#
# [443 rows x 3 columns]

# %%
#save data to csv
preprocessed_df_useful.to_csv('./data_sets/aa2a_preprocessed.csv', index=False, sep=';')
